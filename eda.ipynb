# %%
import pandas as pd

# %%
df = pd.read_csv('input/attacks.csv', encoding='cp1252')

# %%
df
# Out:
#       Case Number         Date    Year        Type    Country  \
# 0      2018.06.25  25-Jun-2018  2018.0     Boating        USA
# 1      2018.06.18  18-Jun-2018  2018.0  Unprovoked        USA
# 2      2018.06.09  09-Jun-2018  2018.0     Invalid        USA
# 3      2018.06.08  08-Jun-2018  2018.0  Unprovoked  AUSTRALIA
# 4      2018.06.04  04-Jun-2018  2018.0    Provoked     MEXICO
# ...           ...          ...     ...         ...        ...
# 25718         NaN          NaN     NaN         NaN        NaN
# 25719         NaN          NaN     NaN         NaN        NaN
# 25720         NaN          NaN     NaN         NaN        NaN
# 25721         NaN          NaN     NaN         NaN        NaN
# 25722          xx          NaN     NaN         NaN        NaN
#
#                   Area                        Location     Activity  \
# 0           California     Oceanside, San Diego County     Paddling
# 1              Georgia  St. Simon Island, Glynn County     Standing
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25723 entries, 0 to 25722
# Data columns (total 24 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Case Number             8702 non-null   object
#  1   Date                    6302 non-null   object
#  2   Year                    6300 non-null   float64
#  3   Type                    6298 non-null   object
#  4   Country                 6252 non-null   object
#  5   Area                    5847 non-null   object
#  6   Location                5762 non-null   object
#  7   Activity                5758 non-null   object
#  8   Name                    6092 non-null   object
#  9   Sex                     5737 non-null   object
#  10  Age                     3471 non-null   object
#  11  Injury                  6274 non-null   object
#  12  Fatal (Y/N)             5763 non-null   object
#  13  Time                    2948 non-null   object
# ...

# %%
df.shape
# Out:
# (25723, 24)

# %%
df.describe()
# Out:
#               Year  original order
# count  6300.000000     6309.000000
# mean   1927.272381     3155.999683
# std     281.116308     1821.396206
# min       0.000000        2.000000
# 25%    1942.000000     1579.000000
# 50%    1977.000000     3156.000000
# 75%    2005.000000     4733.000000
# max    2018.000000     6310.000000

# %%
df.columns
# Out:
# Index(['Case Number', 'Date', 'Year', 'Type', 'Country', 'Area', 'Location',
#        'Activity', 'Name', 'Sex ', 'Age', 'Injury', 'Fatal (Y/N)', 'Time',
#        'Species ', 'Investigator or Source', 'pdf', 'href formula', 'href',
#        'Case Number.1', 'Case Number.2', 'original order', 'Unnamed: 22',
#        'Unnamed: 23'],
#       dtype='object')

# %%
df.head(10)
# Out:
#     Case Number         Date    Year        Type    Country             Area  \
# 0    2018.06.25  25-Jun-2018  2018.0     Boating        USA       California
# 1    2018.06.18  18-Jun-2018  2018.0  Unprovoked        USA          Georgia
# 2    2018.06.09  09-Jun-2018  2018.0     Invalid        USA           Hawaii
# 3    2018.06.08  08-Jun-2018  2018.0  Unprovoked  AUSTRALIA  New South Wales
# 4    2018.06.04  04-Jun-2018  2018.0    Provoked     MEXICO           Colima
# 5  2018.06.03.b  03-Jun-2018  2018.0  Unprovoked  AUSTRALIA  New South Wales
# 6  2018.06.03.a  03-Jun-2018  2018.0  Unprovoked     BRAZIL       Pernambuco
# 7    2018.05.27  27-May-2018  2018.0  Unprovoked        USA          Florida
# 8  2018.05.26.b  26-May-2018  2018.0  Unprovoked        USA          Florida
# 9  2018.05.26.a  26-May-2018  2018.0  Unprovoked        USA          Florida
#
#                                             Location      Activity  \
# ...

# %%
df.tail(10)
# Out:
#       Case Number Date  Year Type Country Area Location Activity Name Sex   \
# 25713         NaN  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
# 25714         NaN  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
# 25715         NaN  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
# 25716         NaN  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
# 25717         NaN  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
# 25718         NaN  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
# 25719         NaN  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
# 25720         NaN  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
# 25721         NaN  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
# 25722          xx  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
#
#        ... Species  Investigator or Source  pdf href formula href  \
# 25713  ...      NaN                    NaN  NaN          NaN  NaN
# ...

# %%
df.sample(frac=0.0005)
# Out:
#         Case Number                  Date    Year        Type  \
# 24526           NaN                   NaN     NaN         NaN
# 9068            NaN                   NaN     NaN         NaN
# 4296   1955.04.13.R  Reported 13-Apr-1955  1955.0  Unprovoked
# 17164           NaN                   NaN     NaN         NaN
# 15418           NaN                   NaN     NaN         NaN
# 16355           NaN                   NaN     NaN         NaN
# 4421   1952.00.00.b                  1952  1952.0  Unprovoked
# 23009           NaN                   NaN     NaN         NaN
# 10846           NaN                   NaN     NaN         NaN
# 3800     1962.08.19           19-Aug-1962  1962.0  Unprovoked
# 6642              0                   NaN     NaN         NaN
# 25600           NaN                   NaN     NaN         NaN
# 17520           NaN                   NaN     NaN         NaN
#
#                 Country                  Area  \
# 24526               NaN                   NaN
# ...

# %%
df["Activity"].describe()
# Out:
# count        5758
# unique       1532
# top       Surfing
# freq          971
# Name: Activity, dtype: object

# %%
pd.isnull(df["Activity"]).sum()
# Out:
# 19965

# %%
df["Injury"].head(10)
# Out:
# 0    No injury to occupant, outrigger canoe and pad...
# 1                           Minor injury to left thigh
# 2         Injury to left lower leg from surfboard skeg
# 3                            Minor injury to lower leg
# 4    Lacerations to leg & hand shark PROVOKED INCIDENT
# 5                              No injury, board bitten
# 6                                                FATAL
# 7              Minor injury to foot. PROVOKED INCIDENT
# 8                                Lower left leg bitten
# 9                                 Minor injury to foot
# Name: Injury, dtype: object

# %%
df["Injury"].describe()
# Out:
# count      6274
# unique     3737
# top       FATAL
# freq        802
# Name: Injury, dtype: object

# %%
pd.isnull(df["Injury"]).sum()
# Out:
# 19449

# %%
df["Sex "].describe()
# Out:
# count     5737
# unique       6
# top          M
# freq      5094
# Name: Sex , dtype: object

# %%
df["Sex "].unique()
# Out:
# array(['F', 'M', nan, 'M ', 'lli', 'N', '.'], dtype=object)

# %%
df[(df["Sex "]=="M ") | (df["Sex "]=="lli") | (df["Sex "]=="N") | (df["Sex "]==".")]
# Out:
#        Case Number                  Date    Year          Type  \
# 563     2014.04.22           22-Apr-2014  2014.0    Unprovoked
# 1587    2005.05.15           15-May-2005  2005.0    Unprovoked
# 1624  2004.11.11.b           11-Nov-2004  2004.0    Unprovoked
# 4938    1934.07.11           11-Jul-1934  1934.0       Boating
# 5437  1908.06.02.R  Reported 02-Jun-1908  1908.0  Sea Disaster
# 6131  1801.12.18.R  Reported 18-Dec-1801  1801.0      Provoked
#
#                Country             Area  \
# 563                USA          Florida
# 1587         AUSTRALIA       Queensland
# 1624               USA       California
# 4938         AUSTRALIA  New South Wales
# 5437  PAPUA NEW GUINEA      New Britain
# 6131               NaN              NaN
#
#                                             Location  \
# 563                     Cocoa Beach, Brevard  County
# 1587                        50 km east of Townsville
# 1624  Bunkers, Humboldt Bay, Eureka, Humboldt County
# ...

# %%
pd.isnull(df["Sex "]).sum()
# Out:
# 19986
